# %%
# https://api.hh.ru/dictionaries

import contextlib
import io
import json
import sys
from typing import List, Dict

import requests
from neo4j import GraphDatabase

"I"
# Out:
# 'I'

# %%
params = {
        'text': 'NAME:Аналитик',  # Текст фильтра. В имени должно быть слово "Аналитик"
        'area': 1,  # Поиск ощуществляется по вакансиям города Москва
        'page': 2,  # Индекс страницы поиска на HH
        'per_page': 100,  # Кол-во вакансий на 1 странице
        'describe_arguments': True
}

# %%
# VACANCIES
req = requests.get('https://api.hh.ru/vacancies', params)
response = req.content.decode()
req.close()

response = json.loads(response)
response
# Out:
# {'items': [{'id': '49179171',
#    'premium': False,
#    'name': 'Аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-26T11:32:22+0300',
#    'created_at': '2021-11-26T11:32:22+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49179171',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49179171?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49179171',
#    'relations': [],
#    'employer': {'id': '2428532',
#     'name': 'Toughbyte',
#     'url': 'https://api.hh.ru/employers/2428532',
#     'alternate_url': 'https://hh.ru/employer/2428532',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2131654.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/422395.png',
#      '240': 'https://hhcdn.ru/employer-logo/2131655.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2428532',
#     'trusted': True},
#    'snippet': {'requirement': 'Требуемый опыт: Участие в роли бизнес-аналитика / системного аналитика в команде разработки ПО или внедрения крупного интеграционного ИТ проекта (как...',
#     'responsibility': '1. Анализ предметной области: - сбор информации о деятельности Заказчика, аудит существующих бизнес-процессов с целью выявления «узких» мест. - '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49849282',
#    'premium': False,
#    'name': 'Аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': None,
#     'street': None,
#     'building': None,
#     'description': None,
#     'lat': None,
#     'lng': None,
#     'raw': 'Москва',
#     'metro': None,
#     'metro_stations': [],
#     'id': '312290'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-22T17:55:29+0300',
#    'created_at': '2021-11-22T17:55:29+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49849282',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49849282?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49849282',
#    'relations': [],
#    'employer': {'id': '49357',
#     'name': 'МАГНИТ, Розничная сеть',
#     'url': 'https://api.hh.ru/employers/49357',
#     'alternate_url': 'https://hh.ru/employer/49357',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/626117.jpg',
#      '240': 'https://hhcdn.ru/employer-logo/2945621.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/2945620.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=49357',
#     'trusted': True},
#    'snippet': {'requirement': 'Уверенное знание SQL, MS Excel. Опыт работы в направлении клиентской аналитики от 1 года. Знание языка Python будет преимуществом. ',
#     'responsibility': 'Аналитическая поддержка активностей, проводимых направлением целевого маркетинга. Подготовка требований к автоматизированной отчетности в рамках направления клиентской аналитики. Подготовка сегментации для...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '48376893',
#    'premium': False,
#    'name': 'Бизнес-аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Новодмитровская улица',
#     'building': '2к1',
#     'description': None,
#     'lat': 55.804941,
#     'lng': 37.589922,
#     'raw': 'Москва, Новодмитровская улица, 2к1',
#     'metro': {'station_name': 'Дмитровская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.35',
#      'line_id': '9',
#      'lat': 55.808056,
#      'lng': 37.581734},
#     'metro_stations': [{'station_name': 'Дмитровская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.35',
#       'line_id': '9',
#       'lat': 55.808056,
#       'lng': 37.581734}],
#     'id': '6504114'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-23T19:28:01+0300',
#    'created_at': '2021-11-23T19:28:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48376893',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48376893?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48376893',
#    'relations': [],
#    'employer': {'id': '4578674',
#     'name': 'CHECKME.RU',
#     'url': 'https://api.hh.ru/employers/4578674',
#     'alternate_url': 'https://hh.ru/employer/4578674',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/730172.png',
#      '240': 'https://hhcdn.ru/employer-logo/3361773.png',
#      '90': 'https://hhcdn.ru/employer-logo/3361772.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4578674',
#     'trusted': True},
#    'snippet': {'requirement': 'Мы начали масштабироваться и поэтому ищем грамотного аналитика, который сделает опыт взаимодействия пользователей приятным и запоминающимся. Вы будете в команде...',
#     'responsibility': 'Вести процесс на всех этапах: погружаться в бизнес-задачу и прорабатывать её, ставить задачи на разработку, контролировать выполнение.  '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': True},
#   {'id': '48271928',
#    'premium': False,
#    'name': 'Аналитик',
#    'department': None,
#    'has_test': True,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 60000, 'to': 60000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Большой Головин переулок',
#     'building': '15',
#     'description': None,
#     'lat': 55.769535,
#     'lng': 37.628783,
#     'raw': 'Москва, Большой Головин переулок, 15',
#     'metro': {'station_name': 'Сухаревская',
#      'line_name': 'Калужско-Рижская',
#      'station_id': '6.137',
#      'line_id': '6',
#      'lat': 55.772315,
#      'lng': 37.63285},
#     'metro_stations': [{'station_name': 'Сухаревская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.137',
#       'line_id': '6',
#       'lat': 55.772315,
#       'lng': 37.63285},
#      {'station_name': 'Трубная',
#       'line_name': 'Люблинско-Дмитровская',
#       'station_id': '10.177',
#       'line_id': '10',
#       'lat': 55.76771,
#       'lng': 37.621926},
#      {'station_name': 'Цветной бульвар',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.154',
#       'line_id': '9',
#       'lat': 55.771653,
#       'lng': 37.620466}],
#     'id': '2565723'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-25T10:36:07+0300',
#    'created_at': '2021-11-25T10:36:07+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48271928',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48271928?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48271928',
#    'relations': [],
#    'employer': {'id': '4005237',
#     'name': 'ГКУ города Москвы Московский центр развития социальных технологий',
#     'url': 'https://api.hh.ru/employers/4005237',
#     'alternate_url': 'https://hh.ru/employer/4005237',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=4005237',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (юридическое, экономическое, ГМУ, техническое). Опыт работы в органах исполнительной власти приветствуется. Владение Excel, Word, Power Point. ',
#     'responsibility': 'Поиск, структурирование и анализ текстовой информации. Количественный анализ данных в Excel. Систематизация и статистическая обработка поступающей информации. Написание отчетов и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49108483',
#    'premium': False,
#    'name': 'Аналитик по управлению данными (Аналитик проекта)',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 60000, 'to': 120000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Инновационный центр Сколково',
#     'building': None,
#     'description': None,
#     'lat': 55.693662,
#     'lng': 37.349749,
#     'raw': 'Москва, Инновационный центр Сколково',
#     'metro': None,
#     'metro_stations': [],
#     'id': '752690'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-24T11:32:17+0300',
#    'created_at': '2021-11-24T11:32:17+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49108483',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49108483?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49108483',
#    'relations': [],
#    'employer': {'id': '2670061',
#     'name': 'Ailet',
#     'url': 'https://api.hh.ru/employers/2670061',
#     'alternate_url': 'https://hh.ru/employer/2670061',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3781355.png',
#      '240': 'https://hhcdn.ru/employer-logo/3781356.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/835118.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2670061',
#     'trusted': True},
#    'snippet': {'requirement': 'Уверенное владение Excel (продвинутый пользователь, умение писать макросы). Знание английского языка (разговорный)-общение с международными клиентами. Опыт взаимодействия с клиентами. ',
#     'responsibility': 'Подготовка и настройка системы на этапе внедрения. Настройка мастер-данных и заведение метрик. Настройка алгоритмов. Работа с брендблоками. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '48726669',
#    'premium': False,
#    'name': 'Аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 160000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Новослободская улица',
#     'building': '73с1',
#     'description': None,
#     'lat': 55.790367,
#     'lng': 37.589805,
#     'raw': 'Москва, Новослободская улица, 73с1',
#     'metro': {'station_name': 'Савеловская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.128',
#      'line_id': '9',
#      'lat': 55.794054,
#      'lng': 37.587163},
#     'metro_stations': [{'station_name': 'Савеловская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.128',
#       'line_id': '9',
#       'lat': 55.794054,
#       'lng': 37.587163}],
#     'id': '1089197'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-22T16:11:10+0300',
#    'created_at': '2021-11-22T16:11:10+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48726669',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48726669?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48726669',
#    'relations': [],
#    'employer': {'id': '3151408',
#     'name': 'Ассоциация IPChain',
#     'url': 'https://api.hh.ru/employers/3151408',
#     'alternate_url': 'https://hh.ru/employer/3151408',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/644675.jpg',
#      '90': 'https://hhcdn.ru/employer-logo/3019848.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3019849.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3151408',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт на позиции бизнес или системного аналитика от 3 лет. Опыт проектирования, декомпозиции и приемки задач. Опыт взаимодействия с заказчиком. ',
#     'responsibility': 'Сбор, уточнение, анализ, описание и декомпозиция требований заказчика. Постановка задач разработчикам и дизайнерам. Разработка технической и пользовательской документации.'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49906066',
#    'premium': False,
#    'name': 'Продуктовый аналитик (Product analyst)',
#    'department': {'id': '7172-7172-it',
#     'name': 'Лента, федеральная розничная сеть, IT '},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-24T11:20:15+0300',
#    'created_at': '2021-11-24T11:20:15+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49906066',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49906066?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49906066',
#    'relations': [],
#    'employer': {'id': '7172',
#     'name': 'Лента, федеральная розничная сеть',
#     'url': 'https://api.hh.ru/employers/7172',
#     'alternate_url': 'https://hh.ru/employer/7172',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3857704.png',
#      '90': 'https://hhcdn.ru/employer-logo/3857703.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/854207.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=7172',
#     'trusted': True},
#    'snippet': {'requirement': 'Имеешь опыт работы в рознице, онлайн-проектах. Уверенно работаешь в Python и пишешь SQL запросы. Хорошо знаешь математику и математическую...',
#     'responsibility': 'Проверять продуктовые гипотезы (проводить эксперименты, А/В тесты). Оценивать потенциал внедрения фичей и участвовать в приоритезации продуктового бэклога. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49885580',
#    'premium': False,
#    'name': 'Аналитик систем мотивации',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-23T16:22:31+0300',
#    'created_at': '2021-11-23T16:22:31+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49885580',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49885580?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49885580',
#    'relations': [],
#    'employer': {'id': '3915906',
#     'name': 'HR ONLINE',
#     'url': 'https://api.hh.ru/employers/3915906',
#     'alternate_url': 'https://hh.ru/employer/3915906',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/3244112.png',
#      '240': 'https://hhcdn.ru/employer-logo/3244113.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/700749.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3915906',
#     'trusted': True},
#    'snippet': {'requirement': 'Знание Excel (работа с большим массивом данных, поиск и корректировка информации в массиве, ВПР, формулы, сводные таблицы). Знание Oracle SQL. ',
#     'responsibility': 'Участие в разработке, создании и поддержании в актуальном состоянии систем материальной мотивации. Поддержка в актуальном состоянии модели систем мотивации и...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '45572778',
#    'premium': False,
#    'name': 'Продуктовый аналитик / Маркетинговый аналитик (BI аналитик)',
#    'department': {'id': '816144-816144-office', 'name': 'ВкусВилл. Офис'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-25T09:09:47+0300',
#    'created_at': '2021-11-25T09:09:47+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=45572778',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/45572778?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/45572778',
#    'relations': [],
#    'employer': {'id': '816144',
#     'name': 'ВкусВилл',
#     'url': 'https://api.hh.ru/employers/816144',
#     'alternate_url': 'https://hh.ru/employer/816144',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2396014.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/2396013.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/488565.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=816144',
#     'trusted': True},
#    'snippet': {'requirement': 'Владение SQL. Опыт проведения А/В тестов. Опыт построения отчётов в визуализаторах типа Power BI, Tableau, Qlickview, Reporting services или...',
#     'responsibility': 'Разработка и оптимизации отчетов и дэшбордов. Исследование данных, отслеживание взаимосвязей. Помощь бизнесу в выборе и проверке гипотез,проведение экспериментов, А...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49870632',
#    'premium': False,
#    'name': 'Бизнес-аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-26T11:38:03+0300',
#    'created_at': '2021-11-26T11:38:03+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49870632',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49870632?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49870632',
#    'relations': [],
#    'employer': {'id': '2766864',
#     'name': 'Лаборатория институционального проектного инжиниринга',
#     'url': 'https://api.hh.ru/employers/2766864',
#     'alternate_url': 'https://hh.ru/employer/2766864',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2066563.png',
#      '90': 'https://hhcdn.ru/employer-logo/2066562.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/406121.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2766864',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование. Опыт участия в проекте по разработке ПО в качестве бизнес-аналитика от 2-х лет. Развитые коммуникационные навыки. ',
#     'responsibility': 'Сбор, анализ и документирование бизнес-требований. Анализ, описание и оптимизация бизнес-процессов. Проектирование работы программы акселерации. Разработка требований к функциональности...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49130700',
#    'premium': False,
#    'name': 'Старший аналитик по работе с данными / BI',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': True,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 200000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': '2-й Кожевнический переулок',
#     'building': '12',
#     'description': None,
#     'lat': 55.725164,
#     'lng': 37.64745,
#     'raw': 'Москва, 2-й Кожевнический переулок, 12',
#     'metro': {'station_name': 'Крестьянская застава',
#      'line_name': 'Люблинско-Дмитровская',
#      'station_id': '10.63',
#      'line_id': '10',
#      'lat': 55.732278,
#      'lng': 37.665325},
#     'metro_stations': [{'station_name': 'Крестьянская застава',
#       'line_name': 'Люблинско-Дмитровская',
#       'station_id': '10.63',
#       'line_id': '10',
#       'lat': 55.732278,
#       'lng': 37.665325},
#      {'station_name': 'Павелецкая',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.101',
#       'line_id': '2',
#       'lat': 55.729741,
#       'lng': 37.638693},
#      {'station_name': 'Павелецкая',
#       'line_name': 'Кольцевая',
#       'station_id': '5.102',
#       'line_id': '5',
#       'lat': 55.731414,
#       'lng': 37.636294},
#      {'station_name': 'Пролетарская',
#       'line_name': 'Таганско-Краснопресненская',
#       'station_id': '7.62',
#       'line_id': '7',
#       'lat': 55.731546,
#       'lng': 37.666917}],
#     'id': '6149046'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-24T20:03:31+0300',
#    'created_at': '2021-11-24T20:03:31+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49130700',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49130700?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49130700',
#    'relations': [],
#    'employer': {'id': '5593615',
#     'name': 'БиАй Продакшн',
#     'url': 'https://api.hh.ru/employers/5593615',
#     'alternate_url': 'https://hh.ru/employer/5593615',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/872334.png',
#      '90': 'https://hhcdn.ru/employer-logo/3930211.png',
#      '240': 'https://hhcdn.ru/employer-logo/3930212.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5593615',
#     'trusted': True},
#    'snippet': {'requirement': 'Релевантный опыт в области анализа данных (сбор, обработка, анализ и визуализация данных, синтез результатов и их коммуникации клиенту) – более 2...',
#     'responsibility': 'Быть частью команды по продукту (бизнес-приложениям) и поддерживать ее в раннем прототипировании, разработке MVP и дальнейшем развитии бизнес-приложений. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '47620430',
#    'premium': True,
#    'name': 'Ведущий аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'проспект Мира',
#     'building': '13с1',
#     'description': None,
#     'lat': 55.776335,
#     'lng': 37.631793,
#     'raw': 'Москва, проспект Мира, 13с1',
#     'metro': None,
#     'metro_stations': [],
#     'id': '416694'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-23T14:53:57+0300',
#    'created_at': '2021-11-23T14:53:57+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=47620430',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/47620430?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/47620430',
#    'relations': [],
#    'employer': {'id': '46525',
#     'name': 'ПРОМОМЕД',
#     'url': 'https://api.hh.ru/employers/46525',
#     'alternate_url': 'https://hh.ru/employer/46525',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/481744.png',
#      '240': 'https://hhcdn.ru/employer-logo/2368829.png',
#      '90': 'https://hhcdn.ru/employer-logo/2368828.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=46525',
#     'trusted': True},
#    'snippet': {'requirement': 'Уверенное владение ПО: MS Excel (PowerQuery, PowerPivot), MS Access (написание запросов на SQL), MS PowerPoint, 1С. Высшее образование (математическое...',
#     'responsibility': 'Обработка, консолидация и анализ первичных продаж компании. Обработка, консолидация и анализ еженедельных/ежемесячных отчетов по вторичным продажам. Обработка, консолидация и...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49649963',
#    'premium': False,
#    'name': 'Аналитик технологий AI',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 140000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-24T19:21:01+0300',
#    'created_at': '2021-11-24T19:21:01+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49649963',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49649963?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49649963',
#    'relations': [],
#    'employer': {'id': '5769438',
#     'name': 'Глобус ИТ',
#     'url': 'https://api.hh.ru/employers/5769438',
#     'alternate_url': 'https://hh.ru/employer/5769438',
#     'logo_urls': None,
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5769438',
#     'trusted': True},
#    'snippet': {'requirement': 'Знания в технологической сфере ( AI, хранение данных). Умение работать с поиском Open source технологий на Github. Высшее образование (техническое/маркетинг...',
#     'responsibility': 'Анализ рынков технологий AI (новости, исследования, разработка). Составление обзоров, презентаций и аналитических отчетов по нейросетям и их прикладному применению. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '48381359',
#    'premium': False,
#    'name': 'Младший аналитик / Аналитик по рискам',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Василисы Кожиной',
#     'building': '1',
#     'description': None,
#     'lat': 55.737502,
#     'lng': 37.504789,
#     'raw': 'Москва, улица Василисы Кожиной, 1',
#     'metro': None,
#     'metro_stations': [],
#     'id': '886412'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-23T18:23:22+0300',
#    'created_at': '2021-11-23T18:23:22+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48381359',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48381359?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48381359',
#    'relations': [],
#    'employer': {'id': '1191643',
#     'name': 'ID Finance',
#     'url': 'https://api.hh.ru/employers/1191643',
#     'alternate_url': 'https://hh.ru/employer/1191643',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/498295.png',
#      '90': 'https://hhcdn.ru/employer-logo/2434933.png',
#      '240': 'https://hhcdn.ru/employer-logo/2434934.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1191643',
#     'trusted': True},
#    'snippet': {'requirement': 'Отличное знание SQL, Excel. Аналитический склад ума. Опыт работы в рисках/продуктах в банке или финтехе. Знание Python/ClickHouse будет...',
#     'responsibility': 'Запуск и реализация проектов направленных для достижения бюджетных риск-метрик и проектов смежных подразделениях. Анализ и мониторинг состояния портфеля, скор...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '48019305',
#    'premium': False,
#    'name': 'Аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 100000, 'to': 120000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Таганская улица',
#     'building': '9',
#     'description': None,
#     'lat': 55.740938,
#     'lng': 37.660045,
#     'raw': 'Москва, Таганская улица, 9',
#     'metro': None,
#     'metro_stations': [],
#     'id': '6573055'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-22T17:41:17+0300',
#    'created_at': '2021-11-22T17:41:17+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48019305',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48019305?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48019305',
#    'relations': [],
#    'employer': {'id': '2537115',
#     'name': 'Розничная сеть МТС',
#     'url': 'https://api.hh.ru/employers/2537115',
#     'alternate_url': 'https://hh.ru/employer/2537115',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/669644.png',
#      '240': 'https://hhcdn.ru/employer-logo/3119709.png',
#      '90': 'https://hhcdn.ru/employer-logo/3119708.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2537115',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы не менее 1 года (приветствуется опыт работы в ритейле/логистике на аналогичной позиции). Аналитический склад ума, умение работать...',
#     'responsibility': 'Настройка совместно с бизнес-пользователями системы регулярных и операционных отчетов логистики (от разработки ТЗ до приема в продуктив от ИТ). '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '46947342',
#    'premium': False,
#    'name': 'Аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Павловская улица',
#     'building': '7',
#     'description': None,
#     'lat': 55.719972,
#     'lng': 37.628262,
#     'raw': 'Москва, Павловская улица, 7',
#     'metro': {'station_name': 'Серпуховская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.37',
#      'line_id': '9',
#      'lat': 55.726548,
#      'lng': 37.624792},
#     'metro_stations': [{'station_name': 'Серпуховская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.37',
#       'line_id': '9',
#       'lat': 55.726548,
#       'lng': 37.624792}],
#     'id': '2414306'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-22T17:58:31+0300',
#    'created_at': '2021-11-22T17:58:31+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=46947342',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/46947342?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/46947342',
#    'relations': [],
#    'employer': {'id': '72615',
#     'name': 'Martinex',
#     'url': 'https://api.hh.ru/employers/72615',
#     'alternate_url': 'https://hh.ru/employer/72615',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1792139.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/1792138.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/337468.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=72615',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование, желательно математика, статистика, экономика, маркетинг. Опыт работы на позиции аналитика в области продаж/маркетинга в торгово-производственной компании...',
#     'responsibility': 'Выстраивание системы сквозной аналитики в компании. Аналитика в разрезе Категорий/Брендов/SKU; аналитика клиентской базы и дистрибуции; аналитика в разрезе...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '47658164',
#    'premium': False,
#    'name': 'SFE analyst / аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 150000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Вятская улица',
#     'building': '27с13',
#     'description': None,
#     'lat': 55.796607,
#     'lng': 37.580032,
#     'raw': 'Москва, Вятская улица, 27с13',
#     'metro': {'station_name': 'Савеловская',
#      'line_name': 'Серпуховско-Тимирязевская',
#      'station_id': '9.128',
#      'line_id': '9',
#      'lat': 55.794054,
#      'lng': 37.587163},
#     'metro_stations': [{'station_name': 'Савеловская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.128',
#       'line_id': '9',
#       'lat': 55.794054,
#       'lng': 37.587163}],
#     'id': '627613'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-26T00:52:00+0300',
#    'created_at': '2021-11-26T00:52:00+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=47658164',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/47658164?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/47658164',
#    'relations': [],
#    'employer': {'id': '112537',
#     'name': 'Кьези Фармасьютикалс',
#     'url': 'https://api.hh.ru/employers/112537',
#     'alternate_url': 'https://hh.ru/employer/112537',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3845504.png',
#      '90': 'https://hhcdn.ru/employer-logo/3845503.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/851157.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=112537',
#     'trusted': True},
#    'snippet': {'requirement': 'Strong analytical skills. High level of IMS database usage. Strong knowledge of MS Excel (including VBA). Document management system skills. ',
#     'responsibility': 'Lead call plan preparation and adjustments process. Provide administrative business support for CRM related processes (cycle plans generation, customer segmentation...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49689503',
#    'premium': False,
#    'name': 'Продуктовый аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Рочдельская улица',
#     'building': '15с11-11А',
#     'description': None,
#     'lat': 55.755728,
#     'lng': 37.564455,
#     'raw': 'Москва, Рочдельская улица, 15с11-11А',
#     'metro': None,
#     'metro_stations': [],
#     'id': '6156816'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-25T17:51:52+0300',
#    'created_at': '2021-11-25T17:51:52+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49689503',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49689503?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49689503',
#    'relations': [],
#    'employer': {'id': '5488399',
#     'name': 'Самокат (ООО Умное пространство)',
#     'url': 'https://api.hh.ru/employers/5488399',
#     'alternate_url': 'https://hh.ru/employer/5488399',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3944400.png',
#      '90': 'https://hhcdn.ru/employer-logo/3944399.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/875881.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5488399',
#     'trusted': True},
#    'snippet': {'requirement': 'У тебя есть базовые знания в теории вероятностей и статистике, и ты применяешь их на практике. Понимаешь, где нужно проводить...',
#     'responsibility': 'Результаты твоей работы - это не просто цифры, а выводы и рекомендации, которые приводят к изменениям. Для тебя не проблема обработать...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49741284',
#    'premium': False,
#    'name': 'Бизнес-аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Коровий Вал',
#     'building': '5с1',
#     'description': None,
#     'lat': 55.728849,
#     'lng': 37.620321,
#     'raw': 'Москва, улица Коровий Вал, 5с1',
#     'metro': {'station_name': 'Добрынинская',
#      'line_name': 'Кольцевая',
#      'station_id': '5.36',
#      'line_id': '5',
#      'lat': 55.728994,
#      'lng': 37.622533},
#     'metro_stations': [{'station_name': 'Добрынинская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.36',
#       'line_id': '5',
#       'lat': 55.728994,
#       'lng': 37.622533},
#      {'station_name': 'Октябрьская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.94',
#       'line_id': '6',
#       'lat': 55.731232,
#       'lng': 37.612851},
#      {'station_name': 'Серпуховская',
#       'line_name': 'Серпуховско-Тимирязевская',
#       'station_id': '9.37',
#       'line_id': '9',
#       'lat': 55.726548,
#       'lng': 37.624792}],
#     'id': '1079022'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-24T10:14:17+0300',
#    'created_at': '2021-11-24T10:14:17+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49741284',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49741284?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49741284',
#    'relations': [],
#    'employer': {'id': '1329',
#     'name': 'Европлан',
#     'url': 'https://api.hh.ru/employers/1329',
#     'alternate_url': 'https://hh.ru/employer/1329',
#     'logo_urls': {'90': 'https://hhcdn.ru/employer-logo/2607657.png',
#      '240': 'https://hhcdn.ru/employer-logo/2607658.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/541546.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1329',
#     'trusted': True},
#    'snippet': {'requirement': 'Навыки анализа данных, поиска закономерностей и отклонений. Опыт подготовки бизнес-требований. Навыки работы в качестве заказчика для технических специалистов. ',
#     'responsibility': 'Работа над ростом показателей воронки продаж канала. Увеличение кол-ва активных партнеров и привлечение новых партнеров. Оптимизация загрузки менеджеров по...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '43047558',
#    'premium': False,
#    'name': 'Системный аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 200000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-24T16:23:42+0300',
#    'created_at': '2021-11-24T16:23:42+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=43047558',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/43047558?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/43047558',
#    'relations': [],
#    'employer': {'id': '89953',
#     'name': 'FunBox',
#     'url': 'https://api.hh.ru/employers/89953',
#     'alternate_url': 'https://hh.ru/employer/89953',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/763397.png',
#      '90': 'https://hhcdn.ru/employer-logo/3494545.png',
#      '240': 'https://hhcdn.ru/employer-logo/3494546.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=89953',
#     'trusted': True},
#    'snippet': {'requirement': 'Умение структурировать полученные знания и грамотно излагать свои мысли. Желание развиваться и изучать новое. Умение задавать правильные вопросы и обращать...',
#     'responsibility': 'Анализировать огромное количество данных абонентов и помогают рекламодателям отправлять сообщения нужным людям в нужное время. Отслеживать перемещение сотрудников в реальном...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49119643',
#    'premium': False,
#    'name': 'Продуктовый аналитик/Аналитик баз данных',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Калуга',
#     'street': 'улица Циолковского',
#     'building': '10',
#     'description': None,
#     'lat': 54.515847,
#     'lng': 36.240572,
#     'raw': 'Калуга, улица Циолковского, 10',
#     'metro': None,
#     'metro_stations': [],
#     'id': '6128468'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-24T14:53:24+0300',
#    'created_at': '2021-11-24T14:53:24+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49119643',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49119643?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49119643',
#    'relations': [],
#    'employer': {'id': '5428084',
#     'name': 'A Soft',
#     'url': 'https://api.hh.ru/employers/5428084',
#     'alternate_url': 'https://hh.ru/employer/5428084',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/911612.png',
#      '240': 'https://hhcdn.ru/employer-logo/4087136.png',
#      '90': 'https://hhcdn.ru/employer-logo/4087135.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=5428084',
#     'trusted': True},
#    'snippet': {'requirement': 'Образование высшее в сфере маркетинга, экономики, прикладной математики, социологии - желательно. Опыт работы в продуктовой аналитике - от 2-х лет. ',
#     'responsibility': 'Сервисы для взаимодействия с контролирующими органами. Электронный документооборот. Высоконагруженные информационные системы. Решения на базе технологий искусственного интеллекта и больших данных. '},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49849152',
#    'premium': False,
#    'name': 'Системный аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 250000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-25T17:51:32+0300',
#    'created_at': '2021-11-25T17:51:32+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49849152',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49849152?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49849152',
#    'relations': [],
#    'employer': {'id': '859839',
#     'name': 'Techno Diasoft',
#     'url': 'https://api.hh.ru/employers/859839',
#     'alternate_url': 'https://hh.ru/employer/859839',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/589371.png',
#      '90': 'https://hhcdn.ru/employer-logo/589370.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/126735.gif'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=859839',
#     'trusted': True},
#    'snippet': {'requirement': 'Системное мышление, умение формировать представление о функционале из разрозненных требований. Грамотная устная и письменная речь, умение находить общий язык как...',
#     'responsibility': 'Анализ и согласование бизнес-требований, полученных от заказчиков: проверка на полноту и непротиворечивость. Подготовка спецификаций в рамках реализуемых фич, формирование...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49706026',
#    'premium': False,
#    'name': 'Аналитик SQL',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-26T11:05:58+0300',
#    'created_at': '2021-11-26T11:05:58+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49706026',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49706026?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49706026',
#    'relations': [],
#    'employer': {'id': '81984',
#     'name': 'Национальная служба взыскания',
#     'url': 'https://api.hh.ru/employers/81984',
#     'alternate_url': 'https://hh.ru/employer/81984',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/667122.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/667121.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/213727.JPG'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=81984',
#     'trusted': True},
# ...
#    'salary': {'from': 200000, 'to': 300000, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': '3-я улица Ямского Поля',
#     'building': '9',
#     'description': None,
#     'lat': 55.781626,
#     'lng': 37.580894,
#     'raw': 'Москва, 3-я улица Ямского Поля, 9',
#     'metro': {'station_name': 'Белорусская',
#      'line_name': 'Замоскворецкая',
#      'station_id': '2.19',
#      'line_id': '2',
#      'lat': 55.777439,
#      'lng': 37.582107},
#     'metro_stations': [{'station_name': 'Белорусская',
#       'line_name': 'Замоскворецкая',
#       'station_id': '2.19',
#       'line_id': '2',
#       'lat': 55.777439,
#       'lng': 37.582107}],
#     'id': '5573620'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-26T09:28:09+0300',
#    'created_at': '2021-11-26T09:28:09+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49172331',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49172331?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49172331',
#    'relations': [],
#    'employer': {'id': '2268880',
#     'name': 'AnyClass',
#     'url': 'https://api.hh.ru/employers/2268880',
#     'alternate_url': 'https://hh.ru/employer/2268880',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/787394.png',
#      '240': 'https://hhcdn.ru/employer-logo/3590468.png',
#      '90': 'https://hhcdn.ru/employer-logo/3590467.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=2268880',
#     'trusted': True},
#    'snippet': {'requirement': 'Релевантный опыт от 3 лет. Опыт управления командой от 3 человек. Владение GA, GDS (Python, SQL - крайне желательно). ',
#     'responsibility': 'Сбор команды для построения ETL-системы и внедрения BI аналитики. Создание ETL-системы на основе AirFlow для сбора данных из...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49436333',
#    'premium': False,
#    'name': 'Продуктовый аналитик EN',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Варшавское шоссе',
#     'building': '118к1',
#     'description': None,
#     'lat': 55.631768,
#     'lng': 37.618022,
#     'raw': 'Москва, Варшавское шоссе, 118к1',
#     'metro': None,
#     'metro_stations': [],
#     'id': '113125'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-23T17:10:03+0300',
#    'created_at': '2021-11-23T17:10:03+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49436333',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49436333?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49436333',
#    'relations': [],
#    'employer': {'id': '76650',
#     'name': 'iiko, Компания Aйко',
#     'url': 'https://api.hh.ru/employers/76650',
#     'alternate_url': 'https://hh.ru/employer/76650',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/214881.png',
#      '90': 'https://hhcdn.ru/employer-logo/591608.png',
#      '240': 'https://hhcdn.ru/employer-logo/591609.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=76650',
#     'trusted': True},
#    'snippet': {'requirement': 'Высшее образование (можно последний курс, техническое). Опыт работы аналитиком от 1-2 лет. Умение и готовность анализировать, структурировать большие объемы...',
#     'responsibility': 'Сбор требований к ПО у клиентов (РФ и зарубежные), анализ информации. Документация требований к ПО. Разработка постановок и спецификаций для...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '48835837',
#    'premium': False,
#    'name': 'Аналитик ОСБУ',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': None, 'to': 100000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'улица Шаболовка',
#     'building': '12',
#     'description': None,
#     'lat': 55.7230648615,
#     'lng': 37.6103205595,
#     'raw': 'Москва, улица Шаболовка, 12',
#     'metro': {'station_name': 'Октябрьская',
#      'line_name': 'Кольцевая',
#      'station_id': '5.93',
#      'line_id': '5',
#      'lat': 55.729264,
#      'lng': 37.611049},
#     'metro_stations': [{'station_name': 'Октябрьская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.93',
#       'line_id': '5',
#       'lat': 55.729264,
#       'lng': 37.611049},
#      {'station_name': 'Октябрьская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.94',
#       'line_id': '6',
#       'lat': 55.731232,
#       'lng': 37.612851},
#      {'station_name': 'Шаболовская',
#       'line_name': 'Калужско-Рижская',
#       'station_id': '6.157',
#       'line_id': '6',
#       'lat': 55.718828,
#       'lng': 37.607892}],
#     'id': '2472103'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-21T11:24:13+0300',
#    'created_at': '2021-11-21T11:24:13+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48835837',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48835837?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48835837',
#    'relations': [],
#    'employer': {'id': '3112915',
#     'name': 'Синтегро консалтинг',
#     'url': 'https://api.hh.ru/employers/3112915',
#     'alternate_url': 'https://hh.ru/employer/3112915',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/3848936.png',
#      '90': 'https://hhcdn.ru/employer-logo/3848935.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/852015.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3112915',
#     'trusted': True},
#    'snippet': {'requirement': 'Понимать бухгалтерский и налоговый учет. Понимать общую архитектуру 1С. Желательно иметь опыт работы аналитиком либо в поддержке 1С. ',
#     'responsibility': 'Консультировать пользователей по вопросам работы системы, анализировать возникшие ошибки, разбираться в бухгалтерском и налоговом учете. Ставить задачи разработчикам. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49793455',
#    'premium': False,
#    'name': 'Аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': None,
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': {'city': 'Москва',
#     'street': 'Большой Дровяной переулок',
#     'building': '6',
#     'description': None,
#     'lat': 55.743755,
#     'lng': 37.65638,
#     'raw': 'Москва, Большой Дровяной переулок, 6',
#     'metro': {'station_name': 'Таганская',
#      'line_name': 'Кольцевая',
#      'station_id': '5.76',
#      'line_id': '5',
#      'lat': 55.742396,
#      'lng': 37.653334},
#     'metro_stations': [{'station_name': 'Таганская',
#       'line_name': 'Кольцевая',
#       'station_id': '5.76',
#       'line_id': '5',
#       'lat': 55.742396,
#       'lng': 37.653334}],
#     'id': '377835'},
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-19T15:58:33+0300',
#    'created_at': '2021-11-19T15:58:33+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49793455',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49793455?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49793455',
#    'relations': [],
#    'employer': {'id': '8703',
#     'name': 'ПиР, Группа компаний',
#     'url': 'https://api.hh.ru/employers/8703',
#     'alternate_url': 'https://hh.ru/employer/8703',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/2367817.jpeg',
#      '90': 'https://hhcdn.ru/employer-logo/2367816.jpeg',
#      'original': 'https://hhcdn.ru/employer-logo-original/481491.jpg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=8703',
#     'trusted': True},
#    'snippet': {'requirement': 'Образование - экономическое, математическое, финансовое. Опыт работы в FMCG - от 1 года. Умение работать как с обработанными, так и необработанными массивами...',
#     'responsibility': 'Поиск, сбор и анализ аналитической информации (внутренние источники, внешние рыночные источники). Анализ рынков присутствия Компании (FMCG) - емкость, структура, динамика, прогнозы. '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49779206',
#    'premium': False,
#    'name': 'Аналитик',
#    'department': None,
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 130000, 'to': 150000, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-19T11:06:20+0300',
#    'created_at': '2021-11-19T11:06:20+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49779206',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49779206?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49779206',
#    'relations': [],
#    'employer': {'id': '176941',
#     'name': 'Азиатско-Тихоокеанский Банк',
#     'url': 'https://api.hh.ru/employers/176941',
#     'alternate_url': 'https://hh.ru/employer/176941',
#     'logo_urls': {'240': 'https://hhcdn.ru/employer-logo/1855327.png',
#      '90': 'https://hhcdn.ru/employer-logo/1855326.png',
#      'original': 'https://hhcdn.ru/employer-logo-original/353266.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=176941',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы от 1 года в качестве аналитика в банке или финтех-компании. Отличное знание Excel. Базовой знание SQL, Python...',
#     'responsibility': 'Участие в разработке и развитии карточных программ лояльности. Отслеживание ключевых метрик по программам лояльности. Развитие продуктовой отчетности. Взаимодействие с финансово...'},
#    'contacts': None,
#    'schedule': {'id': 'remote', 'name': 'Удаленная работа'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '49472976',
#    'premium': False,
#    'name': 'Аналитик',
#    'department': {'id': '1947314-1947314-ancor', 'name': 'ANCOR'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 170000, 'to': None, 'currency': 'RUR', 'gross': True},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-19T17:19:38+0300',
#    'created_at': '2021-11-19T17:19:38+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49472976',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/49472976?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/49472976',
#    'relations': [],
#    'employer': {'id': '1947314',
#     'name': 'ANCOR',
#     'url': 'https://api.hh.ru/employers/1947314',
#     'alternate_url': 'https://hh.ru/employer/1947314',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/785003.png',
#      '240': 'https://hhcdn.ru/employer-logo/3580904.png',
#      '90': 'https://hhcdn.ru/employer-logo/3580903.png'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=1947314',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы в отделах планирования в компаниях отрасли FMCG или электроники. Уверенный пользователь Excel (сводные таблицы, макросы, сложные формулы). ',
#     'responsibility': 'Сбор данных, необходимых для планирования спроса. Самостоятельный расчет и согласование прогноза продаж и отгрузок с представителями рынков, с учетом всех...'},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False},
#   {'id': '48341254',
#    'premium': False,
#    'name': 'Аналитик МФСО',
#    'department': {'id': '3529-3529-it', 'name': 'Сбер. IT'},
#    'has_test': False,
#    'response_letter_required': False,
#    'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#    'salary': {'from': 250000, 'to': None, 'currency': 'RUR', 'gross': False},
#    'type': {'id': 'open', 'name': 'Открытая'},
#    'address': None,
#    'response_url': None,
#    'sort_point_distance': None,
#    'published_at': '2021-11-19T11:49:18+0300',
#    'created_at': '2021-11-19T11:49:18+0300',
#    'archived': False,
#    'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=48341254',
#    'insider_interview': None,
#    'url': 'https://api.hh.ru/vacancies/48341254?host=hh.ru',
#    'alternate_url': 'https://hh.ru/vacancy/48341254',
#    'relations': [],
#    'employer': {'id': '3529',
#     'name': 'Сбербанк',
#     'url': 'https://api.hh.ru/employers/3529',
#     'alternate_url': 'https://hh.ru/employer/3529',
#     'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#      '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#      '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#     'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#     'trusted': True},
#    'snippet': {'requirement': 'Опыт работы (не менее 3-х лет) с реляционными СУБД (Oracle или MS SQL или Teradata) в качестве аналитика/разработчика. ',
#     'responsibility': 'Подготовка функциональных и бизнес требований в проектах по направлениям «Управленческая отчетность» и «Отчетность МСФО» (основной проект – внедрение стандарта МСФО17). '},
#    'contacts': None,
#    'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#    'working_days': [],
#    'working_time_intervals': [],
#    'working_time_modes': [],
#    'accept_temporary': False}],
#  'found': 7855,
#  'pages': 20,
#  'per_page': 100,
#  'page': 2,
#  'clusters': None,
#  'arguments': [{'argument': 'area',
#    'value': '1',
#    'value_description': 'Москва',
#    'disable_url': 'https://api.hh.ru/vacancies?describe_arguments=true&per_page=100&text=NAME%3A%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA',
#    'cluster_group': {'id': 'area', 'name': 'Регион'}},
#   {'argument': 'text',
#    'value': 'NAME:Аналитик',
#    'value_description': None,
#    'disable_url': 'https://api.hh.ru/vacancies?area=1&describe_arguments=true&per_page=100',
#    'cluster_group': None},
#   {'argument': 'page',
#    'value': '2',
#    'value_description': None,
#    'disable_url': 'https://api.hh.ru/vacancies?area=1&describe_arguments=true&per_page=100&text=NAME%3A%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA',
#    'cluster_group': None},
#   {'argument': 'per_page',
#    'value': '100',
#    'value_description': None,
#    'disable_url': 'https://api.hh.ru/vacancies?area=1&describe_arguments=true&text=NAME%3A%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA',
#    'cluster_group': None}],
#  'alternate_url': 'https://hh.ru/search/vacancy?area=1&clusters=true&enable_snippets=true&items_on_page=100&page=2&text=NAME%3A%D0%90%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA'}

# %%
list(response.keys())
# Out:
# ['items',
#  'found',
#  'pages',
#  'per_page',
#  'page',
#  'clusters',
#  'arguments',
#  'alternate_url']

# %%
# d = response['items'][0]
items: List[Dict] = response['items']
item = items[1]
item
# Out:
# {'id': '49548884',
#  'premium': True,
#  'name': 'Аналитик данных',
#  'department': {'id': '3529-3529-prof', 'name': 'Сбер для экспертов'},
#  'has_test': False,
#  'response_letter_required': False,
#  'area': {'id': '1', 'name': 'Москва', 'url': 'https://api.hh.ru/areas/1'},
#  'salary': None,
#  'type': {'id': 'open', 'name': 'Открытая'},
#  'address': None,
#  'response_url': None,
#  'sort_point_distance': None,
#  'published_at': '2021-11-17T10:05:28+0300',
#  'created_at': '2021-11-17T10:05:28+0300',
#  'archived': False,
#  'apply_alternate_url': 'https://hh.ru/applicant/vacancy_response?vacancyId=49548884',
#  'insider_interview': None,
#  'url': 'https://api.hh.ru/vacancies/49548884?host=hh.ru',
#  'alternate_url': 'https://hh.ru/vacancy/49548884',
#  'relations': [],
#  'employer': {'id': '3529',
#   'name': 'Сбербанк',
#   'url': 'https://api.hh.ru/employers/3529',
#   'alternate_url': 'https://hh.ru/employer/3529',
#   'logo_urls': {'original': 'https://hhcdn.ru/employer-logo-original/868362.JPG',
#    '90': 'https://hhcdn.ru/employer-logo/3914323.jpeg',
#    '240': 'https://hhcdn.ru/employer-logo/3914324.jpeg'},
#   'vacancies_url': 'https://api.hh.ru/vacancies?employer_id=3529',
#   'trusted': True},
#  'snippet': {'requirement': 'Высшее образование техническое или экономическое. Опыт анализа больших объемов данных, построения моделей, прогнозирования на будущие периоды или отсутствие опыта, но...',
#   'responsibility': 'Поиск и анализ данных из разрозненных источников, разработка и анализ математических моделей. Визуализация и интерпретация полученных результатов анализа. '},
#  'contacts': None,
#  'schedule': {'id': 'fullDay', 'name': 'Полный день'},
#  'working_days': [],
#  'working_time_intervals': [],
#  'working_time_modes': [],
#  'accept_temporary': False}

# %%
fields = ["name"]

# %%
area = {'id': '1', 'parent_id': '113', 'name': 'Москва', 'areas': []}
p_area = {'id': '113',
          'parent_id': None,
          'name': 'Россия'}
currency = {'name': 'RUR'}
employer = {'id': 4714154, 'name': 'Ельмикеев Евгений Иванович'}
schedule = {'id': 'remote', 'name': 'Удаленная работа'}
vacancy_type = {'id': 'open', 'name': 'Открытая'}
vacancy = {'id': '49154439',
           'name': 'Аналитик бизнес-процессов Amo CRM',
           'has_test': False,
           'salary_from': 70000,
           'salary_to': 120000,
           'published_at': '2021-11-04T14:52:20+0300',
           'created_at': '2021-11-04T14:52:20+0300',
           'requirement': 'Опыт работы от 1 года. Обязательное понимание ключевых метрик бизнеса. Опыт работы в amoCRM. Знание специфических метрик в отраслях будет...',
           'responsibility': 'Общаться с клиентами, понимать бизнес-задачу клиента. Формировать предложение по решению, составить Т3 для разработчиков. Настраивать сервисы; СRM-cистема...'
           }


vacancy2 = {'id': '48621910',
           'name': 'Финансовый аналитик',
           'has_test': False,
           'published_at': '2021-11-04T14:52:20+0300',
           'created_at': '2021-11-04T14:52:20+0300',
           'requirement': 'Высшее профессиональное образование (финансы, экономика, математика). Уверенный пользователь ПК (MSOffice), отличное владение пакетом Excel. Уверенный/продвинутый пользователь 1С, БИТ.Финанс...',
           'responsibility': 'Формирование управленческой отчетности, сбор и аналитика данных. Настраивание процесса бюджетирования, бюджетного контроля и управления. Построение управленческой отчетности для пользователей внутри...'
           }

# %%
# AREAS
req = requests.get('https://api.hh.ru/areas/6000')
data = req.content.decode()
req.close()

data = json.loads(data)
data
# Out:
# {'id': '6000',
#  'parent_id': '1913',
#  'name': 'Ясная Поляна (Тульская область)',
#  'areas': []}

# %%
len(data)
data
# list(data.keys())
# Out:
# {'description': 'Not Found',
#  'errors': [{'type': 'not_found'}],
#  'request_id': '1637512285987eb219648c7faccec54d'}
